# %%
# =====================================================
# PIPELINE FAULT DETECTION MODEL
# =====================================================
# Author: Oluwakpelumi
# Dataset: scada_pipeline.csv
# Goal: Predict whether the pipeline is Faulty or Normal
# =====================================================

# 1️⃣ IMPORT LIBRARIES

# %%
import pandas as pd 
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt 

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV ,RandomizedSearchCV

# %%
# 2️⃣ LOAD DATA
path = r"C:\Users\PC\Desktop\PIPE Leakage\Project 12 SCADA kagggle\scada_pipeline.csv"
df = pd.read_csv(path)

# %%
print(df.head())
print(df.info())
print(df.describe().T)
print(df.columns.tolist())

printdf.nunique()
printdf.isna().sum

printdf.isnull().sum()

print(df.target).value_counts()

# %%
fault = df[df.target==1]

# %%
fault.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 306 entries, 3 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           306 non-null    object
#  1   segment_id          306 non-null    int64
#  2   pressure            306 non-null    float64
#  3   flow_rate           306 non-null    float64
#  4   temperature         306 non-null    float64
#  5   valve_status        306 non-null    int64
#  6   pump_state          306 non-null    int64
#  7   pump_speed          306 non-null    float64
#  8   compressor_state    306 non-null    int64
#  9   energy_consumption  306 non-null    float64
#  10  alarm_triggered     306 non-null    int64
#  11  event_type          306 non-null    object
#  12  target              306 non-null    int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 33.5+ KB

# %%
fault.describe().T
# Out:
#                     count        mean         std    min      25%       50%  \
# segment_id          306.0   25.908497   14.395746   1.00  13.0000    26.000
# pressure            306.0   79.260131   15.022996  43.11  69.0450    77.315
# flow_rate           306.0    3.987451    1.369277   1.01   2.9050     4.260
# temperature         306.0   32.065621    1.933288  25.92  30.7000    32.115
# valve_status        306.0    0.905229    0.555897   0.00   1.0000     1.000
# pump_state          306.0    0.660131    0.474440   0.00   0.0000     1.000
# pump_speed          306.0  841.801307  622.553981   0.00   0.0000  1132.600
# compressor_state    306.0    0.611111    0.488297   0.00   0.0000     1.000
# energy_consumption  306.0   29.280065   10.595217   7.02  21.8325    30.190
# alarm_triggered     306.0    0.705882    0.456391   0.00   0.0000     1.000
# target              306.0    1.000000    0.000000   1.00   1.0000     1.000
#
#                          75%      max
# segment_id            38.750    50.00
# pressure              90.875   115.30
# flow_rate              4.995     7.53
# temperature           33.320    37.26
# valve_status           1.000     2.00
# pump_state             1.000     1.00
# pump_speed          1356.525  1623.70
# compressor_state       1.000     1.00
# energy_consumption    35.470    58.18
# alarm_triggered        1.000     1.00
# target                 1.000     1.00

# %%
no_fault = df[df.target==0]

# %%
no_fault.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 694 entries, 0 to 998
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           694 non-null    object
#  1   segment_id          694 non-null    int64
#  2   pressure            694 non-null    float64
#  3   flow_rate           694 non-null    float64
#  4   temperature         694 non-null    float64
#  5   valve_status        694 non-null    int64
#  6   pump_state          694 non-null    int64
#  7   pump_speed          694 non-null    float64
#  8   compressor_state    694 non-null    int64
#  9   energy_consumption  694 non-null    float64
#  10  alarm_triggered     694 non-null    int64
#  11  event_type          694 non-null    object
#  12  target              694 non-null    int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 75.9+ KB

# %%
no_fault.describe().T
# Out:
#                     count        mean         std    min      25%       50%  \
# segment_id          694.0   25.674352   14.302363   1.00  14.0000    25.000
# pressure            694.0   74.854352    4.931706  61.37  71.5625    74.880
# flow_rate           694.0    4.522896    0.490921   3.07   4.1825     4.540
# temperature         694.0   32.111873    1.996763  27.08  30.6825    32.125
# valve_status        694.0    0.920749    0.546062   0.00   1.0000     1.000
# pump_state          694.0    0.701729    0.457829   0.00   0.0000     1.000
# pump_speed          694.0  979.251441  644.581231   0.00   0.0000  1336.750
# compressor_state    694.0    0.595101    0.491227   0.00   0.0000     1.000
# energy_consumption  694.0   25.783559    8.410025   5.42  20.7850    25.245
# alarm_triggered     694.0    0.000000    0.000000   0.00   0.0000     0.000
# target              694.0    0.000000    0.000000   0.00   0.0000     0.000
#
#                          75%      max
# segment_id            38.000    50.00
# pressure              78.140    88.82
# flow_rate              4.850     6.15
# temperature           33.445    38.52
# valve_status           1.000     2.00
# pump_state             1.000     1.00
# pump_speed          1435.850  1678.80
# compressor_state       1.000     1.00
# energy_consumption    33.480    39.49
# alarm_triggered        0.000     0.00
# target                 0.000     0.00

# %%
df["event_type"].nunique()
# Out:
# 5

# %%
df["event_type"].unique()
# Out:
# array(['normal', 'blockage', 'degradation', 'surge', 'leak'], dtype=object)

# %%
df["event_type"].value_counts()
# Out:
# event_type
# normal         694
# degradation    135
# leak            65
# surge           61
# blockage        45
# Name: count, dtype: int64

# %%
fault.head(20)
# Out:
#         timestamp  segment_id  pressure  flow_rate  temperature  valve_status  \
# 3   1/1/2024 0:00          16     98.49       1.61        30.61             2
# 8   1/1/2024 0:00          12     69.77       4.40        33.24             1
# 14  1/1/2024 0:00          29     96.02       2.04        28.70             1
# 20  1/1/2024 0:00           4     88.65       1.40        29.61             1
# 21  1/1/2024 0:00           3     84.09       5.45        30.02             1
# 23  1/1/2024 0:00          10     88.19       5.96        30.33             1
# 28  1/1/2024 0:00          45    101.75       2.32        29.35             1
# 32  1/1/2024 0:00           8    101.79       1.49        30.67             1
# 36  1/1/2024 0:00          13     79.14       1.51        33.58             2
# 42  1/1/2024 0:00           7     66.93       4.40        30.97             0
# 43  1/1/2024 0:00          11     56.70       3.19        31.20             1
# 48  1/1/2024 0:00          27     96.66       5.47        30.70             1
# 58  1/1/2024 0:00          18     79.78       3.95        34.49             1
# 62  1/1/2024 0:01          44     71.42       4.18        35.15             1
# 66  1/1/2024 0:01           9     94.53       5.04        29.88             1
# 68  1/1/2024 0:01          49     62.76       2.74        31.92             1
# 69  1/1/2024 0:01          33     77.68       4.90        31.31             1
# 71  1/1/2024 0:01          13     93.95       5.44        33.17             1
# 75  1/1/2024 0:01          48    107.09       5.40        32.64             1
# 79  1/1/2024 0:01          43     77.21       2.26        31.22             0
#
#     pump_state  pump_speed  compressor_state  energy_consumption  \
# 3            1      1368.7                 1               37.07
# 8            0         0.0                 1               24.92
# 14           0         0.0                 1               23.88
# 20           1      1623.7                 0               24.31
# 21           1      1383.2                 0               20.71
# 23           1      1334.5                 1               33.84
# 28           1      1262.9                 0               21.40
# 32           0         0.0                 1               21.95
# 36           1      1326.9                 1               29.59
# 42           1      1288.9                 1               31.39
# 43           1      1572.3                 1               39.55
# 48           1      1224.4                 1               29.72
# 58           1       964.5                 0               31.97
# 62           0         0.0                 0               10.32
# 66           1      1435.8                 1               39.10
# 68           1      1293.3                 1               32.63
# 69           1       864.6                 0               30.04
# 71           0         0.0                 0               10.20
# 75           1      1350.3                 0               23.72
# 79           1      1366.1                 1               35.81
#
#     alarm_triggered   event_type  target
# 3                 1     blockage       1
# 8                 0  degradation       1
# 14                1     blockage       1
# 20                1     blockage       1
# 21                1        surge       1
# 23                1        surge       1
# 28                1     blockage       1
# 32                1     blockage       1
# 36                1     blockage       1
# 42                1         leak       1
# 43                1         leak       1
# 48                1        surge       1
# 58                1  degradation       1
# 62                0  degradation       1
# 66                1        surge       1
# 68                1         leak       1
# 69                1  degradation       1
# 71                1        surge       1
# 75                1        surge       1
# 79                1     blockage       1

# %%
(df.alarm_triggered).value_counts()
# Out:
# alarm_triggered
# 0    784
# 1    216
# Name: count, dtype: int64

# %%
(no_fault.alarm_triggered).value_counts()
# Out:
# alarm_triggered
# 0    694
# Name: count, dtype: int64

# %%
(fault.alarm_triggered).value_counts()
# Out:
# alarm_triggered
# 1    216
# 0     90
# Name: count, dtype: int64

# %%
print("Exporing FAULT")
# Out:
# Exporing FAULT

# %%
alarm = (fault[fault.alarm_triggered == 1])

# %%
no_alarm = (fault[fault.alarm_triggered == 0])

# %%
(alarm[["alarm_triggered", "event_type", "target"]]).head(20)
# Out:
#     alarm_triggered   event_type  target
# 3                 1     blockage       1
# 14                1     blockage       1
# 20                1     blockage       1
# 21                1        surge       1
# 23                1        surge       1
# 28                1     blockage       1
# 32                1     blockage       1
# 36                1     blockage       1
# 42                1         leak       1
# 43                1         leak       1
# 48                1        surge       1
# 58                1  degradation       1
# 66                1        surge       1
# 68                1         leak       1
# 69                1  degradation       1
# 71                1        surge       1
# 75                1        surge       1
# 79                1     blockage       1
# 82                1        surge       1
# 84                1         leak       1

# %%
(no_alarm[["alarm_triggered", "event_type", "target"]]).head(20)
# Out:
#      alarm_triggered   event_type  target
# 8                  0  degradation       1
# 62                 0  degradation       1
# 88                 0  degradation       1
# 97                 0  degradation       1
# 101                0  degradation       1
# 103                0  degradation       1
# 125                0  degradation       1
# 130                0  degradation       1
# 131                0  degradation       1
# 135                0  degradation       1
# 138                0  degradation       1
# 143                0  degradation       1
# 145                0  degradation       1
# 148                0  degradation       1
# 150                0  degradation       1
# 157                0  degradation       1
# 164                0  degradation       1
# 166                0  degradation       1
# 173                0  degradation       1
# 178                0  degradation       1

# %%
(alarm["event_type"]).value_counts()
# Out:
# event_type
# leak           65
# surge          61
# blockage       45
# degradation    45
# Name: count, dtype: int64

# %%
(no_alarm["event_type"]).value_counts()
# Out:
# event_type
# degradation    90
# Name: count, dtype: int64

# %%
features1 =  [
 'pressure',
 'flow_rate',
 'temperature',
 'valve_status',
 'pump_state',
 'pump_speed',
 'compressor_state',
 'energy_consumption'
 ]

# %%
target1 = "target"

# %%
df[features1].corrwith(df["target"])
# Out:
# pressure              0.214237
# flow_rate            -0.275917
# temperature          -0.010788
# valve_status         -0.013038
# pump_state           -0.041412
# pump_speed           -0.098904
# compressor_state      0.015060
# energy_consumption    0.173902
# dtype: float64

# %%
print("=========To predict failure==============")
# MODEL A: BINARY CLASSIFICATION (FAULTY vs NORMAL)
# =============================================================================
# Out:
# =========To predict failure==============

# %%
X1 = df[features1]

# %%
y1 = df[target1]

# %%
X1_train,  X1_test, y1_train, y1_test  = train_test_split(X1,y1 ,test_size=0.2, stratify=y1, random_state=12)

# %%
X1_train.shape
# Out:
# (800, 8)

# %%
X1_test.shape
# Out:
# (200, 8)

# %%
rfc = RandomForestClassifier(n_estimators=200, max_depth=10, class_weight="balanced", random_state=12 )

# %%
rfc.fit(X1_train,y1_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=200,
#                        random_state=12)

# %%
y1_pred = rfc.predict(X1_test)

# %%
print("\n=== RandomForest Results (Clean) ===")
# Out:
# === RandomForest Results (Clean) ===

# %%
accuracy_score(y1_test,y1_pred)
# Out:
# 0.965

# %%
roc_auc_score(y1_test,y1_pred)
# Out:
# 0.9564217478476235

# %%
confusion_matrix(y1_test,y1_pred)
# Out:
# array([[136,   3],
#        [  4,  57]], dtype=int64)

# %%
print(classification_report(y1_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       139
#            1       0.95      0.93      0.94        61
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200

# %%
print("\n=== Tuning BaseModel ===")
# Out:
# === Tuning BaseModel ===

# %%
rf = RandomForestClassifier()

# %%
param_grid=[{
   "n_estimators":[100,200,500],
    "max_depth":[5,10,15,None],
    "min_samples_leaf":[1,2,4],
    "class_weight":["balanced"]
}]

# %%
"""param_grid=[{
   "n_estimators":[100, 200,500],
    "max_depth":[5,10,15,None ],
    "class_weight":["balanced"]
}]"""
# Out:
# 'param_grid=[{\n   "n_estimators":[100, 200,500],\n    "max_depth":[5,10,15,None ],\n    "class_weight":["balanced"]\n}]'

# %%
gridsearch = GridSearchCV(
    estimator = rf,
    param_grid = param_grid,
    cv = 5,
    n_jobs = -1,
    scoring = "accuracy"
)

# %%
best_rfc = gridsearch.fit(X1_train,y1_train)

# %%
best_rfc.best_params_
# Out:
# {'class_weight': 'balanced',
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
best_rfc.best_score_
# Out:
# 0.9350000000000002

# %%
pred2 = best_rfc.predict(X1_test)

# %%
accuracy_score(y1_test,pred2)
# Out:
# 0.975

# %%
roc_auc_score(y1_test,pred2)
# Out:
# 0.9636159924519401

# %%
confusion_matrix(y1_test,pred2)
# Out:
# array([[138,   1],
#        [  4,  57]], dtype=int64)

# %%
print(classification_report(y1_test,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       139
#            1       0.98      0.93      0.96        61
#
#     accuracy                           0.97       200
#    macro avg       0.98      0.96      0.97       200
# weighted avg       0.98      0.97      0.97       200

# %%
model_data ={
    "model":best_rfc,
    "features": X1_train.columns.tolist(),
    "features_dtypes": X1_train.dtypes.to_dict()
}

# %%
joblib.dump(model_data, "m1_fault_detection.plk")
# Out:
# ['m1_fault_detection.plk']

# %%
print("=========To predict what type of Event==============")
# Out:
# =========To predict what type of Event==============

# %%
#========THIS MODEL WILL BE TRAIN ON THE TARGET=1 (Faulty) DATA===========

# %%
fault.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 306 entries, 3 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           306 non-null    object
#  1   segment_id          306 non-null    int64
#  2   pressure            306 non-null    float64
#  3   flow_rate           306 non-null    float64
#  4   temperature         306 non-null    float64
#  5   valve_status        306 non-null    int64
#  6   pump_state          306 non-null    int64
#  7   pump_speed          306 non-null    float64
#  8   compressor_state    306 non-null    int64
#  9   energy_consumption  306 non-null    float64
#  10  alarm_triggered     306 non-null    int64
#  11  event_type          306 non-null    object
#  12  target              306 non-null    int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 33.5+ KB

# %%
fault_df = fault.copy()

# %%
features2 = fault_df.iloc[:,2:10]

# %%
features2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 306 entries, 3 to 999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pressure            306 non-null    float64
#  1   flow_rate           306 non-null    float64
#  2   temperature         306 non-null    float64
#  3   valve_status        306 non-null    int64
#  4   pump_state          306 non-null    int64
#  5   pump_speed          306 non-null    float64
#  6   compressor_state    306 non-null    int64
#  7   energy_consumption  306 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 21.5 KB

# %%
(fault_df["event_type"]).unique()
# Out:
# array(['blockage', 'degradation', 'surge', 'leak'], dtype=object)

# %%
(fault_df["event_type"]).value_counts()
# Out:
# event_type
# degradation    135
# leak            65
# surge           61
# blockage        45
# Name: count, dtype: int64

# %%
labelencoder = LabelEncoder()

# %%
fault_df["fault_type"] = labelencoder.fit_transform(fault_df["event_type"])

# %%
print("\nLabelEncoder classes:")
print(labelencoder.classes_)
# Out:
# LabelEncoder classes:
# ['blockage' 'degradation' 'leak' 'surge']

# %%
# Get the mapping between numbers and original labels
label_mapping = dict(zip(labelencoder.classes_, range(len(labelencoder.classes_))))
print("Label Encoder Mapping:")
for label, number in label_mapping.items():
    print(f"  {number} → {label}")
# Out:
# Label Encoder Mapping:
#   0 → blockage
#   1 → degradation
#   2 → leak
#   3 → surge

# %%
fault_df.columns.tolist()
# Out:
# ['timestamp',
#  'segment_id',
#  'pressure',
#  'flow_rate',
#  'temperature',
#  'valve_status',
#  'pump_state',
#  'pump_speed',
#  'compressor_state',
#  'energy_consumption',
#  'alarm_triggered',
#  'event_type',
#  'target',
#  'fault_type']

# %%
fault_df.head()
# Out:
#         timestamp  segment_id  pressure  flow_rate  temperature  valve_status  \
# 3   1/1/2024 0:00          16     98.49       1.61        30.61             2
# 8   1/1/2024 0:00          12     69.77       4.40        33.24             1
# 14  1/1/2024 0:00          29     96.02       2.04        28.70             1
# 20  1/1/2024 0:00           4     88.65       1.40        29.61             1
# 21  1/1/2024 0:00           3     84.09       5.45        30.02             1
#
#     pump_state  pump_speed  compressor_state  energy_consumption  \
# 3            1      1368.7                 1               37.07
# 8            0         0.0                 1               24.92
# 14           0         0.0                 1               23.88
# 20           1      1623.7                 0               24.31
# 21           1      1383.2                 0               20.71
#
#     alarm_triggered   event_type  target  fault_type
# 3                 1     blockage       1           0
# 8                 0  degradation       1           1
# 14                1     blockage       1           0
# 20                1     blockage       1           0
# 21                1        surge       1           3

# %%
target2 = fault_df.iloc[:,-1]

# %%
target2.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 306 entries, 3 to 999
# Series name: fault_type
# Non-Null Count  Dtype
# --------------  -----
# 306 non-null    int32
# dtypes: int32(1)
# memory usage: 3.6 KB

# %%
X2 = features2

# %%
y2 = target2

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y2, test_size=0.2, stratify=y2 , random_state=12)

# %%
print(f"X2 (test and Train) shape:{X2_test.shape, X2_train.shape}")
# Out:
# X2 (test and Train) shape:((62, 8), (244, 8))

# %%
print(f"y2 (test and Train) shape:{y2_test.shape, y2_train.shape}")
# Out:
# y2 (test and Train) shape:((62,), (244,))

# %%
rfc1 = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    class_weight="balanced",
    random_state=12
)

# %%
rfc1.fit(X2_train,y2_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=200,
#                        random_state=12)

# %%
y2_pred = rfc1.predict(X2_test)

# %%
print(f"{accuracy_score(y2_test,y2_pred):.3f}")
# Out:
# 0.935

# %%
confusion_matrix(y2_test,y2_pred)
# Out:
# array([[ 8,  0,  1,  0],
#        [ 0, 24,  0,  3],
#        [ 0,  0, 13,  0],
#        [ 0,  0,  0, 13]], dtype=int64)

# %%
print(classification_report(y2_test,y2_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94         9
#            1       1.00      0.89      0.94        27
#            2       0.93      1.00      0.96        13
#            3       0.81      1.00      0.90        13
#
#     accuracy                           0.94        62
#    macro avg       0.94      0.94      0.94        62
# weighted avg       0.95      0.94      0.94        62

# %%
#MODEL TUNNING

# %%
rf1 = RandomForestClassifier()

# %%
paramgrid2 = [{
    "n_estimators":[200,500,1000],
    "class_weight":["balanced"],
    "max_depth":[5,10,15,None],
    "min_samples_leaf":[1,2,4],
}]

# %%
gridsearch2 = GridSearchCV(
    estimator = rf1 ,
    param_grid = paramgrid2 ,
    cv = 5,
    n_jobs = -1,
    scoring = "accuracy"
)

# %%
rfc2 = gridsearch2.fit(X2_train,y2_train)

# %%
gridsearch2.best_params_
# Out:
# {'class_weight': 'balanced',
#  'max_depth': 15,
#  'min_samples_leaf': 1,
#  'n_estimators': 200}

# %%
rfc2.best_params_
# Out:
# {'class_weight': 'balanced',
#  'max_depth': 15,
#  'min_samples_leaf': 1,
#  'n_estimators': 200}

# %%
gridsearch2.best_score_
# Out:
# 0.9795068027210885

# %%
rfc2.best_score_
# Out:
# 0.9795068027210885

# %%
pred4 = rfc2.predict(X2_test)

# %%
pred3 = gridsearch2.predict(X2_test)

# %%
print(f"{accuracy_score(y2_test,pred4):.3f}")
# Out:
# 0.952

# %%
print(f"{accuracy_score(y2_test,pred3):.3f}")
# Out:
# 0.952

# %%
confusion_matrix(y2_test,pred3)
# Out:
# array([[ 8,  0,  1,  0],
#        [ 0, 25,  0,  2],
#        [ 0,  0, 13,  0],
#        [ 0,  0,  0, 13]], dtype=int64)

# %%
print(classification_report(y2_test,pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94         9
#            1       1.00      0.93      0.96        27
#            2       0.93      1.00      0.96        13
#            3       0.87      1.00      0.93        13
#
#     accuracy                           0.95        62
#    macro avg       0.95      0.95      0.95        62
# weighted avg       0.96      0.95      0.95        62

# %%
model_data2 ={
    "model":rfc2,
    "features": X1_train.columns.tolist(),
    "features_dtypes": X1_train.dtypes.to_dict()
}
joblib.dump(model_data2, "m2_fault_type.plk")
# Out:
# ['m2_fault_type.plk']

# %%
##TRaining Fault type using another algorithm

# %%
gb = GradientBoostingClassifier(
    n_estimators = 300,
    learning_rate=0.05,
    max_depth=5,
    max_features="sqrt",
    subsample=0.8,
    random_state=12
)

# %%
gb.fit(X2_train,y2_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=5, max_features='sqrt',
#                            n_estimators=300, random_state=12, subsample=0.8)

# %%
gp_pred = gb.predict(X2_test)

# %%
accuracy_score(y2_test,gp_pred)
# Out:
# 0.9516129032258065

# %%
confusion_matrix(y2_test,gp_pred)
# Out:
# array([[ 9,  0,  0,  0],
#        [ 0, 24,  1,  2],
#        [ 0,  0, 13,  0],
#        [ 0,  0,  0, 13]], dtype=int64)

# %%
print(classification_report(y2_test,gp_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.89      0.94        27
#            2       0.93      1.00      0.96        13
#            3       0.87      1.00      0.93        13
#
#     accuracy                           0.95        62
#    macro avg       0.95      0.97      0.96        62
# weighted avg       0.96      0.95      0.95        62

# %%
#MODEL TUNNING

# %%
"""paramgrid3 = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'max_features': ['sqrt', None]
}"""
# Out:
# "paramgrid3 = {\n    'n_estimators': [100, 200, 300],\n    'learning_rate': [0.01, 0.05, 0.1],\n    'max_depth': [3, 5, 7],\n    'subsample': [0.8, 1.0],\n    'max_features': ['sqrt', None]\n}"

# %%
paramgrid3 = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
}

# %%
gridsearch3 = GridSearchCV(
    estimator=gb,
    param_grid=paramgrid3,
    scoring='accuracy',
    cv=2,
    n_jobs=-1,
)

# %%
gridsearch3.fit(X2_train,y2_train)
# Out:
# GridSearchCV(cv=2,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   max_depth=5,
#                                                   max_features='sqrt',
#                                                   n_estimators=300,
#                                                   random_state=12,
#                                                   subsample=0.8),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
gridsearch3.best_score_
# Out:
# 0.9754098360655737

# %%
gridsearch3.best_params_
# Out:
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 300}

# %%
gp_pred2 = gridsearch3.predict(X2_test)

# %%
accuracy_score(y2_test,gp_pred2)
# Out:
# 0.9354838709677419

# %%
confusion_matrix(y2_test,gp_pred2)
# Out:
# array([[ 9,  0,  0,  0],
#        [ 0, 23,  2,  2],
#        [ 0,  0, 13,  0],
#        [ 0,  0,  0, 13]], dtype=int64)

# %%
print(classification_report(y2_test,gp_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.85      0.92        27
#            2       0.87      1.00      0.93        13
#            3       0.87      1.00      0.93        13
#
#     accuracy                           0.94        62
#    macro avg       0.93      0.96      0.94        62
# weighted avg       0.94      0.94      0.94        62

# %%
model_data3 = {
    "model" : gb,
    "features" : X2_train.columns.tolist(),
    "features_dtypes" : X2_train.dtypes.to_dict()
}

# %%
joblib.dump(model_data3, "m3_fault_type.pkl")
# Out:
# ['m3_fault_type.pkl']
